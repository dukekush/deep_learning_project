# %%
import torch
from torchvision import transforms, datasets
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
from helpers import train, evaluation, generate_confusion_matrix
from helpers import plot_accuracy, plot_loss, plot_confusion_matrix

# %%
DATA_PATH = './15SceneData/'
MODELS_PATH = './models/'
PLOTS_PATH = './plots/'
SEMI_SUPERVISED_NAME = 'perturbation_v1.pt'
MODEL_NAME = 'perturbation_supervised'

DEVICE = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

NUM_CLASSES = 15
BATCH_SIZE = 32
NUM_EPOCHS = 100
PATIENCE = 30

# %%
# Load the dataset
# Use same transformations as in the pretext task 'perturbation_classification_v1.ipynb'
train_dataset = datasets.ImageFolder(DATA_PATH + 'train',
                                     transform=transforms.Compose([
                                         transforms.Resize((224, 224)),
                                         transforms.RandomHorizontalFlip(),
                                         transforms.RandomVerticalFlip(),
                                         transforms.ToTensor(),
                                         transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                              std=[0.229, 0.224, 0.225])
                                     ]))

val_dataset = datasets.ImageFolder(DATA_PATH + 'validation',
                                   transform=transforms.Compose([
                                       transforms.Resize((224, 224)),
                                       transforms.ToTensor(),
                                       transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                                              std=[0.229, 0.224, 0.225])
                                   ]))

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

# %%
model = torch.load(MODELS_PATH + SEMI_SUPERVISED_NAME, map_location=DEVICE)

trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
print('Trainable params before freezing feature extraction params: {:,}'.format(trainable).replace(',', ' '))

# Freeze the feature parameters
for feature_param in model.features.parameters():
    feature_param.requires_grad = False

# Change the last layer to output 15 classes
model.classifier = nn.Sequential(
    nn.Dropout(p=0.2, inplace=True),
    nn.Linear(1280, NUM_CLASSES)
)

trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
print('Trainable params after freezing feature extraction params: {:,}'.format(trainable).replace(',', ' '))

print(model.classifier)
# Out:
# Trainable params before freezing feature extraction params: 4 010 110
# Trainable params after freezing feature extraction params: 19 215
# Sequential(
#   (0): Dropout(p=0.2, inplace=True)
#   (1): Linear(in_features=1280, out_features=15, bias=True)
# )

# %%
# Same settings as in the last model of fully-supervised training
optimizer = optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.CrossEntropyLoss()
lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=10, verbose=True)

model.to(DEVICE)

fitted, train_loss, train_acc, val_loss,  val_acc = train(
    model, 
    optimizer,
    loss_fn,
    train_loader, 
    val_loader, 
    lr_scheduler=lr_scheduler,
    num_epochs=NUM_EPOCHS, 
    patience=PATIENCE, 
    device=DEVICE
    )

torch.save(fitted, MODELS_PATH + MODEL_NAME + '.pt')
# Out:
# Epoch [1/100]: 100%|██████████| 47/47 [00:06<00:00,  6.78it/s, train_acc=14.1, train_loss=2.6, val_acc=0, val_loss=inf]
# Epoch [2/100]: 100%|██████████| 47/47 [00:05<00:00,  8.49it/s, train_acc=21.8, train_loss=2.41, val_acc=24.2, val_loss=2.43]
# Epoch [3/100]: 100%|██████████| 47/47 [00:05<00:00,  8.38it/s, train_acc=26.1, train_loss=2.33, val_acc=26.7, val_loss=2.27]
# Epoch [4/100]: 100%|██████████| 47/47 [00:05<00:00,  8.33it/s, train_acc=27.1, train_loss=2.26, val_acc=27.4, val_loss=2.2]
# Epoch [5/100]: 100%|██████████| 47/47 [00:05<00:00,  8.62it/s, train_acc=26.5, train_loss=2.25, val_acc=28.3, val_loss=2.22]
# Epoch [6/100]: 100%|██████████| 47/47 [00:05<00:00,  8.50it/s, train_acc=28.5, train_loss=2.22, val_acc=31, val_loss=2.11]
# Epoch [7/100]: 100%|██████████| 47/47 [00:05<00:00,  8.49it/s, train_acc=27.5, train_loss=2.21, val_acc=34, val_loss=2.02]
# Epoch [8/100]: 100%|██████████| 47/47 [00:05<00:00,  8.52it/s, train_acc=30.5, train_loss=2.14, val_acc=32.3, val_loss=2.07]
# Epoch [9/100]: 100%|██████████| 47/47 [00:07<00:00,  6.07it/s, train_acc=30.7, train_loss=2.12, val_acc=35.3, val_loss=1.99]
# Epoch [10/100]: 100%|██████████| 47/47 [00:07<00:00,  6.05it/s, train_acc=30.7, train_loss=2.11, val_acc=35, val_loss=1.94]
# Epoch [11/100]: 100%|██████████| 47/47 [00:07<00:00,  6.27it/s, train_acc=30, train_loss=2.1, val_acc=35.9, val_loss=1.95]
# Epoch [12/100]: 100%|██████████| 47/47 [00:07<00:00,  6.32it/s, train_acc=33.3, train_loss=2.09, val_acc=36.9, val_loss=1.94]
# Epoch [13/100]: 100%|██████████| 47/47 [00:07<00:00,  6.27it/s, train_acc=32.4, train_loss=2.07, val_acc=36.8, val_loss=1.95]
# Epoch [14/100]: 100%|██████████| 47/47 [00:07<00:00,  5.92it/s, train_acc=33.9, train_loss=2.04, val_acc=36.5, val_loss=1.93]
# Epoch [15/100]: 100%|██████████| 47/47 [00:08<00:00,  5.76it/s, train_acc=35, train_loss=2.02, val_acc=38.1, val_loss=1.9]
# Epoch [16/100]: 100%|██████████| 47/47 [00:08<00:00,  5.61it/s, train_acc=33.7, train_loss=2.01, val_acc=37.4, val_loss=1.9]
# Epoch [17/100]: 100%|██████████| 47/47 [00:07<00:00,  5.92it/s, train_acc=34.8, train_loss=2.02, val_acc=37, val_loss=1.9]
# Epoch [18/100]: 100%|██████████| 47/47 [00:08<00:00,  5.76it/s, train_acc=32.7, train_loss=2.01, val_acc=40.2, val_loss=1.88]
# Epoch [19/100]: 100%|██████████| 47/47 [00:07<00:00,  6.06it/s, train_acc=34.3, train_loss=2.01, val_acc=38.3, val_loss=1.86]
# Epoch [20/100]: 100%|██████████| 47/47 [00:07<00:00,  6.29it/s, train_acc=36.3, train_loss=1.97, val_acc=40.2, val_loss=1.85]
# Epoch [21/100]: 100%|██████████| 47/47 [00:07<00:00,  6.56it/s, train_acc=38.2, train_loss=1.94, val_acc=38.3, val_loss=1.86]
# Epoch [22/100]: 100%|██████████| 47/47 [00:07<00:00,  6.29it/s, train_acc=35.3, train_loss=1.98, val_acc=40.5, val_loss=1.86]
# Epoch [23/100]: 100%|██████████| 47/47 [00:07<00:00,  6.27it/s, train_acc=37, train_loss=1.95, val_acc=39.8, val_loss=1.79]
# Epoch [24/100]: 100%|██████████| 47/47 [00:07<00:00,  6.24it/s, train_acc=37.9, train_loss=1.96, val_acc=39.3, val_loss=1.83]
# Epoch [25/100]: 100%|██████████| 47/47 [00:07<00:00,  6.41it/s, train_acc=38.3, train_loss=1.9, val_acc=42, val_loss=1.77]
# Epoch [26/100]: 100%|██████████| 47/47 [00:07<00:00,  6.22it/s, train_acc=37.1, train_loss=1.92, val_acc=43.5, val_loss=1.77]
# Epoch [27/100]: 100%|██████████| 47/47 [00:07<00:00,  6.31it/s, train_acc=38.7, train_loss=1.9, val_acc=43, val_loss=1.77]
# Epoch [28/100]: 100%|██████████| 47/47 [00:07<00:00,  6.24it/s, train_acc=37.3, train_loss=1.93, val_acc=40.7, val_loss=1.82]
# Epoch [29/100]: 100%|██████████| 47/47 [00:07<00:00,  6.09it/s, train_acc=38.8, train_loss=1.91, val_acc=42, val_loss=1.79]
# Epoch [30/100]: 100%|██████████| 47/47 [00:07<00:00,  6.08it/s, train_acc=38.3, train_loss=1.94, val_acc=41.1, val_loss=1.77]
# Epoch [31/100]: 100%|██████████| 47/47 [00:07<00:00,  6.20it/s, train_acc=40, train_loss=1.88, val_acc=44.6, val_loss=1.72]
# Epoch [32/100]: 100%|██████████| 47/47 [00:07<00:00,  6.21it/s, train_acc=40.9, train_loss=1.88, val_acc=43.6, val_loss=1.77]
# Epoch [33/100]: 100%|██████████| 47/47 [00:07<00:00,  6.11it/s, train_acc=38.9, train_loss=1.85, val_acc=43.9, val_loss=1.72]
# Epoch [34/100]: 100%|██████████| 47/47 [00:07<00:00,  6.14it/s, train_acc=39.1, train_loss=1.88, val_acc=41.8, val_loss=1.75]
# Epoch [35/100]: 100%|██████████| 47/47 [00:07<00:00,  6.09it/s, train_acc=36.8, train_loss=1.91, val_acc=42.9, val_loss=1.74]
# Epoch [36/100]: 100%|██████████| 47/47 [00:08<00:00,  5.86it/s, train_acc=38.9, train_loss=1.86, val_acc=45.4, val_loss=1.74]
# Epoch [37/100]: 100%|██████████| 47/47 [00:07<00:00,  6.01it/s, train_acc=38.8, train_loss=1.88, val_acc=42.1, val_loss=1.77]
# Epoch [38/100]: 100%|██████████| 47/47 [00:07<00:00,  6.01it/s, train_acc=40.1, train_loss=1.86, val_acc=42.8, val_loss=1.73]
# Epoch [39/100]: 100%|██████████| 47/47 [00:07<00:00,  6.03it/s, train_acc=40.4, train_loss=1.85, val_acc=44.9, val_loss=1.69]
# Epoch [40/100]: 100%|██████████| 47/47 [00:07<00:00,  6.20it/s, train_acc=40.7, train_loss=1.83, val_acc=44.4, val_loss=1.7]
# Epoch [41/100]: 100%|██████████| 47/47 [00:07<00:00,  6.17it/s, train_acc=39.2, train_loss=1.87, val_acc=43.1, val_loss=1.71]
# Epoch [42/100]: 100%|██████████| 47/47 [00:07<00:00,  6.18it/s, train_acc=40.7, train_loss=1.86, val_acc=43.8, val_loss=1.73]
# Epoch [43/100]: 100%|██████████| 47/47 [00:07<00:00,  6.13it/s, train_acc=39.7, train_loss=1.86, val_acc=45.7, val_loss=1.69]
# Epoch [44/100]: 100%|██████████| 47/47 [00:07<00:00,  6.18it/s, train_acc=38.7, train_loss=1.84, val_acc=44.8, val_loss=1.7]
# Epoch [45/100]: 100%|██████████| 47/47 [00:07<00:00,  6.21it/s, train_acc=40.3, train_loss=1.86, val_acc=45.2, val_loss=1.71]
# Epoch [46/100]: 100%|██████████| 47/47 [00:07<00:00,  6.37it/s, train_acc=41.6, train_loss=1.84, val_acc=46.2, val_loss=1.67]
# Epoch [47/100]: 100%|██████████| 47/47 [00:07<00:00,  6.31it/s, train_acc=41.8, train_loss=1.83, val_acc=45.9, val_loss=1.68]
# Epoch [48/100]: 100%|██████████| 47/47 [00:07<00:00,  6.10it/s, train_acc=40.7, train_loss=1.79, val_acc=45.5, val_loss=1.68]
# Epoch [49/100]: 100%|██████████| 47/47 [00:07<00:00,  6.12it/s, train_acc=41.1, train_loss=1.8, val_acc=45, val_loss=1.68]
# Epoch [50/100]: 100%|██████████| 47/47 [00:07<00:00,  6.35it/s, train_acc=40, train_loss=1.84, val_acc=46.4, val_loss=1.66]
# Epoch [51/100]: 100%|██████████| 47/47 [00:08<00:00,  5.46it/s, train_acc=40.8, train_loss=1.81, val_acc=43.8, val_loss=1.71]
# Epoch [52/100]: 100%|██████████| 47/47 [00:07<00:00,  6.41it/s, train_acc=40.9, train_loss=1.83, val_acc=45.2, val_loss=1.68]
# Epoch [53/100]: 100%|██████████| 47/47 [00:07<00:00,  6.28it/s, train_acc=42.6, train_loss=1.8, val_acc=46.5, val_loss=1.66]
# Epoch [54/100]: 100%|██████████| 47/47 [00:07<00:00,  6.14it/s, train_acc=39.5, train_loss=1.87, val_acc=46.1, val_loss=1.67]
# Epoch [55/100]: 100%|██████████| 47/47 [00:08<00:00,  5.83it/s, train_acc=40.8, train_loss=1.81, val_acc=47, val_loss=1.65]
# Epoch [56/100]: 100%|██████████| 47/47 [00:07<00:00,  6.15it/s, train_acc=43.4, train_loss=1.78, val_acc=44.1, val_loss=1.69]
# Epoch [57/100]: 100%|██████████| 47/47 [00:07<00:00,  6.12it/s, train_acc=40.2, train_loss=1.78, val_acc=45.3, val_loss=1.71]
# Epoch [58/100]: 100%|██████████| 47/47 [00:11<00:00,  3.96it/s, train_acc=40.9, train_loss=1.79, val_acc=46.5, val_loss=1.67]
# Epoch [59/100]: 100%|██████████| 47/47 [00:11<00:00,  3.93it/s, train_acc=41.7, train_loss=1.82, val_acc=46.8, val_loss=1.67]
# Epoch [60/100]: 100%|██████████| 47/47 [00:11<00:00,  4.02it/s, train_acc=42.6, train_loss=1.78, val_acc=45.2, val_loss=1.68]
# Epoch [61/100]: 100%|██████████| 47/47 [00:12<00:00,  3.91it/s, train_acc=42.2, train_loss=1.81, val_acc=46.8, val_loss=1.61]
# Epoch [62/100]: 100%|██████████| 47/47 [00:11<00:00,  3.93it/s, train_acc=42.1, train_loss=1.77, val_acc=48.8, val_loss=1.61]
# Epoch [63/100]: 100%|██████████| 47/47 [00:09<00:00,  4.71it/s, train_acc=41.4, train_loss=1.79, val_acc=45.9, val_loss=1.63]
# Epoch [64/100]: 100%|██████████| 47/47 [00:10<00:00,  4.50it/s, train_acc=42.9, train_loss=1.79, val_acc=47.4, val_loss=1.64]
# Epoch [65/100]: 100%|██████████| 47/47 [00:10<00:00,  4.58it/s, train_acc=43.8, train_loss=1.75, val_acc=47.7, val_loss=1.6]
# Epoch [66/100]: 100%|██████████| 47/47 [00:11<00:00,  4.04it/s, train_acc=42.7, train_loss=1.79, val_acc=45.6, val_loss=1.64]
# Epoch [67/100]: 100%|██████████| 47/47 [00:11<00:00,  4.22it/s, train_acc=42.5, train_loss=1.77, val_acc=47.1, val_loss=1.67]
# Epoch [68/100]: 100%|██████████| 47/47 [00:12<00:00,  3.90it/s, train_acc=42.6, train_loss=1.77, val_acc=48.4, val_loss=1.62]
# Epoch [69/100]: 100%|██████████| 47/47 [00:11<00:00,  4.06it/s, train_acc=42.6, train_loss=1.78, val_acc=46.1, val_loss=1.64]
# Epoch [70/100]: 100%|██████████| 47/47 [00:11<00:00,  4.23it/s, train_acc=42, train_loss=1.81, val_acc=47.7, val_loss=1.63]
# Epoch [71/100]: 100%|██████████| 47/47 [00:11<00:00,  4.14it/s, train_acc=44.2, train_loss=1.74, val_acc=48.7, val_loss=1.61]
# Epoch [72/100]: 100%|██████████| 47/47 [00:10<00:00,  4.46it/s, train_acc=41.2, train_loss=1.8, val_acc=46.2, val_loss=1.65]
# Epoch [73/100]: 100%|██████████| 47/47 [00:13<00:00,  3.49it/s, train_acc=41.7, train_loss=1.81, val_acc=46.7, val_loss=1.65]
# Epoch [74/100]: 100%|██████████| 47/47 [00:11<00:00,  4.22it/s, train_acc=42, train_loss=1.78, val_acc=47.4, val_loss=1.64]
# Epoch [75/100]: 100%|██████████| 47/47 [00:11<00:00,  4.18it/s, train_acc=41.8, train_loss=1.8, val_acc=49.1, val_loss=1.62]
# Epoch [76/100]: 100%|██████████| 47/47 [00:11<00:00,  4.16it/s, train_acc=45, train_loss=1.74, val_acc=48.2, val_loss=1.61]
# Epoch [77/100]: 100%|██████████| 47/47 [00:11<00:00,  4.02it/s, train_acc=42.5, train_loss=1.79, val_acc=48.6, val_loss=1.61]
# Epoch [78/100]: 100%|██████████| 47/47 [00:09<00:00,  4.95it/s, train_acc=43.5, train_loss=1.77, val_acc=47.1, val_loss=1.62]
# Epoch [79/100]: 100%|██████████| 47/47 [00:10<00:00,  4.45it/s, train_acc=44.3, train_loss=1.73, val_acc=49, val_loss=1.57]
# Epoch [80/100]: 100%|██████████| 47/47 [00:10<00:00,  4.58it/s, train_acc=41.8, train_loss=1.77, val_acc=47.5, val_loss=1.61]
# Epoch [81/100]: 100%|██████████| 47/47 [00:11<00:00,  4.00it/s, train_acc=41.9, train_loss=1.77, val_acc=48.7, val_loss=1.61]
# Epoch [82/100]: 100%|██████████| 47/47 [00:11<00:00,  4.06it/s, train_acc=43.3, train_loss=1.77, val_acc=48.4, val_loss=1.59]
# Epoch [83/100]: 100%|██████████| 47/47 [00:11<00:00,  4.17it/s, train_acc=41.5, train_loss=1.79, val_acc=48.4, val_loss=1.62]
# Epoch [84/100]: 100%|██████████| 47/47 [00:11<00:00,  4.06it/s, train_acc=45.1, train_loss=1.74, val_acc=47, val_loss=1.6]
# Epoch [85/100]: 100%|██████████| 47/47 [00:11<00:00,  4.12it/s, train_acc=43.4, train_loss=1.77, val_acc=47.9, val_loss=1.6]
# Epoch [86/100]: 100%|██████████| 47/47 [00:10<00:00,  4.45it/s, train_acc=44.2, train_loss=1.73, val_acc=48.4, val_loss=1.59]
# Epoch [87/100]: 100%|██████████| 47/47 [00:10<00:00,  4.30it/s, train_acc=43.1, train_loss=1.73, val_acc=48.1, val_loss=1.6]
# Epoch [88/100]: 100%|██████████| 47/47 [00:12<00:00,  3.88it/s, train_acc=42.7, train_loss=1.73, val_acc=46.8, val_loss=1.61]
# Epoch [89/100]: 100%|██████████| 47/47 [00:11<00:00,  4.19it/s, train_acc=43, train_loss=1.75, val_acc=49.7, val_loss=1.58]
# Epoch [90/100]: 100%|██████████| 47/47 [00:10<00:00,  4.28it/s, train_acc=44.5, train_loss=1.74, val_acc=48.2, val_loss=1.59]
# Epoch [91/100]: 100%|██████████| 47/47 [00:10<00:00,  4.28it/s, train_acc=41.4, train_loss=1.79, val_acc=49.1, val_loss=1.6]
# Epoch [92/100]: 100%|██████████| 47/47 [00:11<00:00,  4.21it/s, train_acc=42.5, train_loss=1.76, val_acc=48.4, val_loss=1.61]
# Epoch [93/100]: 100%|██████████| 47/47 [00:10<00:00,  4.41it/s, train_acc=41.2, train_loss=1.75, val_acc=48.8, val_loss=1.57]
# Epoch [94/100]: 100%|██████████| 47/47 [00:11<00:00,  4.19it/s, train_acc=44.9, train_loss=1.74, val_acc=50.5, val_loss=1.54]
# Epoch [95/100]: 100%|██████████| 47/47 [00:11<00:00,  4.25it/s, train_acc=42.5, train_loss=1.76, val_acc=49.4, val_loss=1.61]
# Epoch [96/100]: 100%|██████████| 47/47 [00:11<00:00,  4.21it/s, train_acc=42.9, train_loss=1.75, val_acc=49.6, val_loss=1.55]
# Epoch [97/100]: 100%|██████████| 47/47 [00:11<00:00,  4.08it/s, train_acc=42.2, train_loss=1.74, val_acc=49.4, val_loss=1.6]
# Epoch [98/100]: 100%|██████████| 47/47 [00:11<00:00,  4.22it/s, train_acc=44.1, train_loss=1.72, val_acc=48.8, val_loss=1.59]
# Epoch [99/100]: 100%|██████████| 47/47 [00:10<00:00,  4.32it/s, train_acc=43.7, train_loss=1.74, val_acc=49.4, val_loss=1.6]
# Epoch [100/100]: 100%|██████████| 47/47 [00:10<00:00,  4.46it/s, train_acc=43.9, train_loss=1.77, val_acc=48.1, val_loss=1.63]

# %%
plot_accuracy(train_acc, val_acc, MODEL_NAME, PLOTS_PATH + MODEL_NAME + '_accuracy.png')

# %%
plot_loss(train_loss, val_loss, MODEL_NAME, PLOTS_PATH + MODEL_NAME + '_loss.png')

# %%
_, train_accuracy = evaluation(fitted, train_loader, nn.CrossEntropyLoss(), DEVICE)
_, val_accuracy = evaluation(fitted, val_loader, nn.CrossEntropyLoss(), DEVICE)

print(f'Train accuracy: {train_accuracy*100.:.2f}%')
print(f'Validation accuracy: {val_accuracy*100.:.2f}%')
# Out:
# Train accuracy: 54.47%
# Validation accuracy: 50.49%

# %%
cm = generate_confusion_matrix(fitted, val_loader, DEVICE)

plot_confusion_matrix(
    cm,
    val_loader.dataset.classes,
    'Confusion matrix',
    PLOTS_PATH + MODEL_NAME + '_confusion_matrix.png',
    normalize=False
)
