# %%
import torch
from torchvision import transforms, datasets, models
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim
from helpers import train, evaluation, generate_confusion_matrix
from helpers import plot_accuracy, plot_loss, plot_confusion_matrix

# %%
DATA_PATH = './15SceneData/'
MODELS_PATH = './models/'
PLOTS_PATH = './plots/'
MODEL_NAME = 'efficientnetb0_v1'

DEVICE = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

NUM_CLASSES = 15
BATCH_SIZE = 32
NUM_EPOCHS = 100
PATIENCE = 15

# %% [markdown]
# # Load Data

# %%
# Load the dataset
train_dataset = datasets.ImageFolder(DATA_PATH + 'train',
                                     transform=transforms.Compose([
                                         transforms.Resize((224, 224)),  # EfficientNet requires 3x224x224
                                         transforms.ToTensor()
                                     ]))

val_dataset = datasets.ImageFolder(DATA_PATH + 'validation',
                                   transform=transforms.Compose([
                                       transforms.Resize((224, 224)),
                                       transforms.ToTensor()
                                   ]))

# %% [markdown]
# # Create data loaders

# %%
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=0)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, num_workers=0)

# %% [markdown]
# # Load pretrained model

# %%
model = models.efficientnet_b0(weights='IMAGENET1K_V1')

# Change the classifier part of model to fit our problem
print('BEFORE:', model.classifier)
model.classifier = nn.Sequential(
    nn.Dropout(p=0.2, inplace=True),
    nn.Linear(1280, NUM_CLASSES)
)
print('AFTER:', model.classifier)
# Out:
# BEFORE: Sequential(
#   (0): Dropout(p=0.2, inplace=True)
#   (1): Linear(in_features=1280, out_features=1000, bias=True)
# )
# AFTER: Sequential(
#   (0): Dropout(p=0.2, inplace=True)
#   (1): Linear(in_features=1280, out_features=15, bias=True)
# )

# %%
optimizer = optim.Adam(model.parameters())
loss_fn = nn.CrossEntropyLoss()

model.to(DEVICE)

fitted, train_loss, train_acc, val_loss,  val_acc = train(
    model, 
    optimizer,
    loss_fn,
    train_loader, 
    val_loader, 
    num_epochs=NUM_EPOCHS, 
    patience=PATIENCE, 
    device=DEVICE
    )

torch.save(fitted, MODELS_PATH + MODEL_NAME + '.pt')
# Out:
# Epoch [1/100]: 100%|██████████| 47/47 [00:20<00:00,  2.24it/s, train_acc=63.3, train_loss=2.26, val_acc=0, val_loss=inf]
# Epoch [2/100]: 100%|██████████| 47/47 [00:17<00:00,  2.74it/s, train_acc=79.9, train_loss=2.03, val_acc=72.9, val_loss=2.1]
# Epoch [3/100]: 100%|██████████| 47/47 [00:17<00:00,  2.72it/s, train_acc=81.6, train_loss=2.01, val_acc=73.6, val_loss=2.09]
# Epoch [4/100]: 100%|██████████| 47/47 [00:17<00:00,  2.73it/s, train_acc=81.4, train_loss=2.01, val_acc=79.2, val_loss=2.03]
# Epoch [5/100]: 100%|██████████| 47/47 [00:17<00:00,  2.74it/s, train_acc=83, train_loss=1.99, val_acc=82.7, val_loss=1.99]
# Epoch [6/100]: 100%|██████████| 47/47 [00:17<00:00,  2.75it/s, train_acc=86.1, train_loss=1.96, val_acc=81.3, val_loss=2]
# Epoch [7/100]: 100%|██████████| 47/47 [00:17<00:00,  2.74it/s, train_acc=86.5, train_loss=1.96, val_acc=83.7, val_loss=1.98]
# Epoch [8/100]: 100%|██████████| 47/47 [00:17<00:00,  2.71it/s, train_acc=87.5, train_loss=1.95, val_acc=79.1, val_loss=2.02]
# Epoch [9/100]: 100%|██████████| 47/47 [00:19<00:00,  2.46it/s, train_acc=84.9, train_loss=1.97, val_acc=82.1, val_loss=1.99]
# Epoch [10/100]: 100%|██████████| 47/47 [00:20<00:00,  2.30it/s, train_acc=88.1, train_loss=1.94, val_acc=81, val_loss=2.01]
# Epoch [11/100]: 100%|██████████| 47/47 [00:20<00:00,  2.28it/s, train_acc=90.3, train_loss=1.92, val_acc=87.3, val_loss=1.94]
# Epoch [12/100]: 100%|██████████| 47/47 [00:20<00:00,  2.35it/s, train_acc=89.6, train_loss=1.92, val_acc=82.1, val_loss=2]
# Epoch [13/100]: 100%|██████████| 47/47 [00:20<00:00,  2.33it/s, train_acc=89.9, train_loss=1.92, val_acc=84.3, val_loss=1.98]
# Epoch [14/100]: 100%|██████████| 47/47 [00:21<00:00,  2.23it/s, train_acc=90.2, train_loss=1.92, val_acc=82, val_loss=2]
# Epoch [15/100]: 100%|██████████| 47/47 [00:20<00:00,  2.27it/s, train_acc=90.2, train_loss=1.92, val_acc=79.3, val_loss=2.02]
# Epoch [16/100]: 100%|██████████| 47/47 [00:21<00:00,  2.23it/s, train_acc=91.6, train_loss=1.9, val_acc=85.8, val_loss=1.96]
# Epoch [17/100]: 100%|██████████| 47/47 [00:20<00:00,  2.24it/s, train_acc=92, train_loss=1.9, val_acc=85.5, val_loss=1.96]
# Epoch [18/100]: 100%|██████████| 47/47 [00:20<00:00,  2.32it/s, train_acc=92.4, train_loss=1.89, val_acc=84.9, val_loss=1.97]
# Epoch [19/100]: 100%|██████████| 47/47 [00:19<00:00,  2.35it/s, train_acc=94.1, train_loss=1.88, val_acc=84.5, val_loss=1.97]
# Epoch [20/100]: 100%|██████████| 47/47 [00:17<00:00,  2.68it/s, train_acc=94.9, train_loss=1.87, val_acc=87.5, val_loss=1.94]
# Epoch [21/100]: 100%|██████████| 47/47 [00:17<00:00,  2.72it/s, train_acc=95.2, train_loss=1.87, val_acc=87.7, val_loss=1.94]
# Epoch [22/100]: 100%|██████████| 47/47 [00:17<00:00,  2.73it/s, train_acc=94.3, train_loss=1.88, val_acc=85.9, val_loss=1.96]
# Epoch [23/100]: 100%|██████████| 47/47 [00:17<00:00,  2.72it/s, train_acc=91.5, train_loss=1.9, val_acc=84.2, val_loss=1.97]
# Epoch [24/100]: 100%|██████████| 47/47 [00:17<00:00,  2.72it/s, train_acc=93.4, train_loss=1.88, val_acc=79.7, val_loss=2.02]
# Epoch [25/100]: 100%|██████████| 47/47 [00:17<00:00,  2.72it/s, train_acc=94, train_loss=1.88, val_acc=87.9, val_loss=1.94]
# Epoch [26/100]: 100%|██████████| 47/47 [00:17<00:00,  2.72it/s, train_acc=94.9, train_loss=1.87, val_acc=84.8, val_loss=1.97]
# Epoch [27/100]: 100%|██████████| 47/47 [00:17<00:00,  2.70it/s, train_acc=96.5, train_loss=1.85, val_acc=88.5, val_loss=1.93]
# Epoch [28/100]: 100%|██████████| 47/47 [00:17<00:00,  2.67it/s, train_acc=96.7, train_loss=1.85, val_acc=88.3, val_loss=1.93]
# Epoch [29/100]: 100%|██████████| 47/47 [00:17<00:00,  2.65it/s, train_acc=95.8, train_loss=1.86, val_acc=86.8, val_loss=1.95]
# Epoch [30/100]: 100%|██████████| 47/47 [00:17<00:00,  2.66it/s, train_acc=96.3, train_loss=1.86, val_acc=87.4, val_loss=1.94]
# Epoch [31/100]: 100%|██████████| 47/47 [00:17<00:00,  2.66it/s, train_acc=96.5, train_loss=1.85, val_acc=87.6, val_loss=1.94]
# Epoch [32/100]: 100%|██████████| 47/47 [00:17<00:00,  2.65it/s, train_acc=97.1, train_loss=1.85, val_acc=86, val_loss=1.96]
# Epoch [33/100]: 100%|██████████| 47/47 [00:17<00:00,  2.72it/s, train_acc=97.5, train_loss=1.85, val_acc=86.3, val_loss=1.95]
# Epoch [34/100]: 100%|██████████| 47/47 [00:17<00:00,  2.63it/s, train_acc=98, train_loss=1.84, val_acc=86.8, val_loss=1.95]
# Epoch [35/100]: 100%|██████████| 47/47 [00:17<00:00,  2.67it/s, train_acc=97.1, train_loss=1.85, val_acc=87.8, val_loss=1.94]
# Epoch [36/100]: 100%|██████████| 47/47 [00:17<00:00,  2.67it/s, train_acc=97.2, train_loss=1.85, val_acc=88.1, val_loss=1.93]
# Epoch [37/100]: 100%|██████████| 47/47 [00:17<00:00,  2.65it/s, train_acc=96.5, train_loss=1.85, val_acc=86.4, val_loss=1.95]
# Epoch [38/100]: 100%|██████████| 47/47 [00:17<00:00,  2.67it/s, train_acc=96, train_loss=1.86, val_acc=84.7, val_loss=1.97]
# Epoch [39/100]: 100%|██████████| 47/47 [00:17<00:00,  2.70it/s, train_acc=96.3, train_loss=1.86, val_acc=87.8, val_loss=1.94]
# Epoch [40/100]: 100%|██████████| 47/47 [00:17<00:00,  2.69it/s, train_acc=96.8, train_loss=1.85, val_acc=85.7, val_loss=1.96]
# Epoch [41/100]: 100%|██████████| 47/47 [00:17<00:00,  2.65it/s, train_acc=97.3, train_loss=1.84, val_acc=88.3, val_loss=1.94]
# Early stopping!

# %%
plot_accuracy(train_acc, val_acc, MODEL_NAME, PLOTS_PATH + MODEL_NAME + '_accuracy.png')

# %%
plot_loss(train_loss, val_loss, MODEL_NAME, PLOTS_PATH + MODEL_NAME + '_loss.png')

# %%
_, train_accuracy = evaluation(fitted, train_loader, nn.CrossEntropyLoss(), DEVICE)
_, val_accuracy = evaluation(fitted, val_loader, nn.CrossEntropyLoss(), DEVICE)

print(f'Train accuracy: {train_accuracy*100.:.2f}%')
print(f'Validation accuracy: {val_accuracy*100.:.2f}%')
# Out:
# Train accuracy: 98.07%
# Validation accuracy: 88.48%

# %%
cm = generate_confusion_matrix(fitted, val_loader, DEVICE)

plot_confusion_matrix(
    cm,
    val_loader.dataset.classes,
    'Confusion matrix',
    PLOTS_PATH + MODEL_NAME + '_confusion_matrix.png',
    normalize=False
)
